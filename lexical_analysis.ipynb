# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# %%
# getting data
url = 'https://github.com/BobAdamsEE/SouthParkData/blob/master/All-seasons.csv?raw=true'
df = pd.read_csv(url)

# get rid of new lines
df["Line"] = df["Line"].str.replace('\n', '', regex=True)

# make lower case
df["Line"] = df["Line"].str.lower()

# remove punctuation
def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

df['Line'] = df['Line'].apply(remove_punctuation)

# remove fillers
df["Line"] = df["Line"].str.replace('uh', '', regex=True)
df["Line"] = df["Line"].str.replace('um', '', regex=True)

# %%
# remove stopwords, tokenize and stem
def process_line(text):
    stop_words = set(stopwords.words('english'))
    words = nltk.word_tokenize(text)
    filtered_words = [w for w in words if w.lower() not in stop_words]
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(w) for w in filtered_words]
    return ' '.join(stemmed_words)

df['token_line'] = df['Line'].apply(process_line)

# %%
# remove extremely high or low frequency words from lines


# apply an offensive dictionary, a profanity dictionary, etc
# explicitly validate the words in the dictioary (see political paper)
